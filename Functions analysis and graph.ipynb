# %% [markdown]
# # Functions

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x1 = np.arange(1,10,2)
#print('x1 : ', x1)
x2 = np.linspace(1,10,100)
#print('x2 : ', x2)

plt.figure(1)

plt.plot(x1, np.cos(x1))
plt.plot(x2, np.cos(x2))
plt.show()
