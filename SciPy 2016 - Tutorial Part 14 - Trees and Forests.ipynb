# %% [markdown]
# # Trees and Forests

# %% [markdown]
# Decision trees are fast to train, easy to understand,  and often lead to interpretable models. However trees tend to overfit the data before being able to correctly separate the different classes.
#
# Therefore, in practice we can combine many trees to produce multiple models that generalize better => __The Forest__

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
from figures_lib_2015 import make_dataset
x, y = make_dataset()
print(x.shape)
X = x.reshape(-1, 1)
print(X.shape)

plt.xlabel('Feature X')
plt.ylabel('Target y')
plt.scatter(X, y);
# Out:
# (100,)
# (100, 1)

# %%
from sklearn.tree import DecisionTreeRegressor

reg = DecisionTreeRegressor(max_depth=5)
reg.fit(X,y)

X_fit = np.linspace(-3, 3, 1000).reshape((-1, 1))
y_fit_1 = reg.predict(X_fit)

plt.plot(X_fit.ravel(), y_fit_1, color='blue', label="prediction")
plt.plot(X.ravel(), y, '.k', label="training data")
plt.legend(loc="best");

# %% [markdown]
# ### Decision Tree Classification

# %%
from sklearn.datasets import make_blobs
from sklearn.cross_validation import train_test_split
from sklearn.tree import DecisionTreeClassifier
from figures import plot_2d_separator

X, y = make_blobs(centers=[[0,0],[1,1]], random_state=61526, n_samples = 1000)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

clf = DecisionTreeClassifier(max_depth=3)
clf.fit(X,y)

plot_2d_separator(clf, X, fill=True)
plt.scatter(X_train[:,0], X_train[:,1], c=y_train, s=60, alpha=.6)
plt.scatter(X_test[:,0], X_test[:,1], c=y_test, s=60)
plt.show()

# %%
from figures import plo
